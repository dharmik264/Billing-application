# %%
from pathlib import Path
try:
    from PIL import Image, ImageDraw, ImageFont
except ImportError:
    import subprocess, sys
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'Pillow'])
    from PIL import Image, ImageDraw, ImageFont

text = 'ABCDEFGHIJKLMNOPQRST'
font_size = 24
try:
    font = ImageFont.truetype('arial.ttf', font_size)
except Exception:
    font = ImageFont.load_default()

padding = 16
img_dummy = Image.new('RGB', (1, 1), 'white')
draw = ImageDraw.Draw(img_dummy)
bbox = draw.textbbox((0, 0), text, font=font)
w = bbox[2] - bbox[0]
h = bbox[3] - bbox[1]
img = Image.new('RGB', (w + padding * 2, h + padding * 2), 'white')
draw = ImageDraw.Draw(img)
draw.text((padding, padding), text, fill='black', font=font)
path = Path('bill_line_20_chars_preview.png')
img.save(path)
path.resolve()
# Out:
# WindowsPath('D:/DharmikProject/billing application/bill_line_20_chars_preview.png')

# %%
import subprocess, os
os.chdir(r'd:\DharmikProject\billing application')
for cmd in [['git','status','--short'], ['git','remote','-v']]:
    p = subprocess.run(cmd, capture_output=True, text=True)
    print('CMD:', ' '.join(cmd))
    print('RET:', p.returncode)
    print(p.stdout)
    print(p.stderr)
